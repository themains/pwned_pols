# %% [markdown]
# ### Download and Merge EveryPol Data

# %%
import os
import pandas as pd
import requests
from io import StringIO

# %%
data = pd.read_csv("../data/everypol-walkthrough.csv")
data['row_id'] = data.index + 1
data.head()
# Out:
#                     country                 legislature  \
# 0                     India                   Lok Sabha
# 1                     China  National People’s Congress
# 2  United-States-of-America    House of Representatives
# 3  United-States-of-America    House of Representatives
# 4  United-States-of-America    House of Representatives
#
#                               term  leg_start_year  row_count  \
# 0                   16th Lok Sabha            2014        541
# 1  12th National People’s Congress            2013       2987
# 2                   113th Congress            2013        449
# 3                   114th Congress            2015        447
# 4                   108th Congress            2003        444
#
#    n_unique_emails  person_count_legistype                   ltype  \
# 0              511                     541  unicameral legislature
# 1                0                    2956  unicameral legislature
# 2                0                    1739             lower house
# 3                0                    1739             lower house
# 4                0                    1739             lower house
#
#                                                  url  cc leg_start_date  \
# 0  https://cdn.rawgit.com/everypolitician/everypo...  IN     2014-05-26
# 1  https://cdn.rawgit.com/everypolitician/everypo...  CN     2013-03-05
# 2  https://cdn.rawgit.com/everypolitician/everypo...  US     2013-01-06
# 3  https://cdn.rawgit.com/everypolitician/everypo...  US     2015-01-06
# 4  https://cdn.rawgit.com/everypolitician/everypo...  US     2003-01-06
#
#       lastmod  cc3       pop2024  lastmod_year  row_id
# 0  1557812040  IND  1.441720e+09          2019       1
# 1  1554305411  CHN  1.410132e+09          2019       2
# 2  1557715874  USA  3.366107e+08          2019       3
# 3  1557715874  USA  3.366107e+08          2019       4
# 4  1557715874  USA  3.366107e+08          2019       5

# %%
# Let's filter to CSVs where we have more than 30
print(data.shape)
sm_data = data[data["n_unique_emails"] > 30]
sm_data.shape
# Out:
# (757, 16)
# (116, 16)

# %%
sm_data["n_unique_emails"].describe()
# Out:
# count    116.000000
# mean     116.948276
# std      108.956142
# min       31.000000
# 25%       51.750000
# 50%       73.000000
# 75%      143.250000
# max      646.000000
# Name: n_unique_emails, dtype: float64

# %%
output_folder = "../data/legislature_data"
os.makedirs(output_folder, exist_ok=True)

dfs = []

for _, row in sm_data.iterrows():
    try:
        print(f"Fetching data for {row['country']} - {row['legislature']} - {row['leg_start_year']}")
        response = requests.get(row['url'])
        response.raise_for_status()

        csv_filename = os.path.join(output_folder, f"{row['country']}_{row['legislature']}_{row['leg_start_year']}_{row['row_id']}.csv")
        with open(csv_filename, "wb") as file:
            file.write(response.content)
        print(f"Saved {csv_filename}")

        csv_data = StringIO(response.text)
        df = pd.read_csv(csv_data)

        # Add key
        df["row_id"] = row["row_id"]
    
        dfs.append(df)
    except Exception as e:
        print(f"Failed to process {row['country']} - {row['legislature']} - {row['leg_start_year']}: {e}")
# Out:
# Fetching data for India - Lok Sabha - 2014
# Saved ../data/legislature_data/India_Lok Sabha_2014_1.csv
# Fetching data for Nigeria - Senate - 2015
# Saved ../data/legislature_data/Nigeria_Senate_2015_45.csv
# Fetching data for Nigeria - House of Representatives - 2015
# Saved ../data/legislature_data/Nigeria_House of Representatives_2015_46.csv
# Fetching data for Iran - Majles - 2012
# Saved ../data/legislature_data/Iran_Majles_2012_62.csv
# Fetching data for Iran - Majles - 2016
# Saved ../data/legislature_data/Iran_Majles_2016_63.csv
# Fetching data for Tanzania - National Assembly - 2015
# Saved ../data/legislature_data/Tanzania_National Assembly_2015_110.csv
# Fetching data for Tanzania - National Assembly - 2005
# Saved ../data/legislature_data/Tanzania_National Assembly_2005_111.csv
# Fetching data for Tanzania - National Assembly - 2010
# Saved ../data/legislature_data/Tanzania_National Assembly_2010_113.csv
# Fetching data for UK - House of Commons - 2015
# Saved ../data/legislature_data/UK_House of Commons_2015_114.csv
# Fetching data for UK - House of Commons - 2010
# Saved ../data/legislature_data/UK_House of Commons_2010_115.csv
# Fetching data for UK - House of Commons - 1997
# Saved ../data/legislature_data/UK_House of Commons_1997_116.csv
# Fetching data for UK - House of Commons - 2001
# Saved ../data/legislature_data/UK_House of Commons_2001_117.csv
# Fetching data for UK - House of Commons - 2017
# Saved ../data/legislature_data/UK_House of Commons_2017_118.csv
# Fetching data for UK - House of Commons - 2005
# Saved ../data/legislature_data/UK_House of Commons_2005_119.csv
# Fetching data for South-Africa - National Assembly - 2014
# Saved ../data/legislature_data/South-Africa_National Assembly_2014_124.csv
# Fetching data for Italy - Senate - 2013
# Saved ../data/legislature_data/Italy_Senate_2013_125.csv
# Fetching data for Italy - Senate - 2018
# Saved ../data/legislature_data/Italy_Senate_2018_127.csv
# Fetching data for Kenya - National Assembly - 2013
# Saved ../data/legislature_data/Kenya_National Assembly_2013_128.csv
# Fetching data for Colombia - Cámara de Representantes - 2018
# Saved ../data/legislature_data/Colombia_Cámara de Representantes_2018_130.csv
# Fetching data for Colombia - Cámara de Representantes - 2014
# Saved ../data/legislature_data/Colombia_Cámara de Representantes_2014_131.csv
# Fetching data for South-Korea - National Assembly - 2016
# Saved ../data/legislature_data/South-Korea_National Assembly_2016_133.csv
# Fetching data for South-Korea - National Assembly - 2012
# Saved ../data/legislature_data/South-Korea_National Assembly_2012_134.csv
# Fetching data for Uganda - Parliament - 2016
# Saved ../data/legislature_data/Uganda_Parliament_2016_135.csv
# Fetching data for Uganda - Parliament - 2011
# Saved ../data/legislature_data/Uganda_Parliament_2011_136.csv
# Fetching data for Canada - House of Commons - 2011
# Saved ../data/legislature_data/Canada_House of Commons_2011_148.csv
# Fetching data for Canada - Senate - 2015
# Saved ../data/legislature_data/Canada_Senate_2015_149.csv
# Fetching data for Canada - House of Commons - 2015
# Saved ../data/legislature_data/Canada_House of Commons_2015_150.csv
# Fetching data for Nepal - Constituent Assembly - 2014
# Saved ../data/legislature_data/Nepal_Constituent Assembly_2014_184.csv
# Fetching data for Cameroon - Assemblée Nationale - 2013
# Saved ../data/legislature_data/Cameroon_Assemblée Nationale_2013_195.csv
# Fetching data for Australia - House of Representatives - 2016
# Saved ../data/legislature_data/Australia_House of Representatives_2016_201.csv
# Fetching data for Australia - House of Representatives - 2010
# Saved ../data/legislature_data/Australia_House of Representatives_2010_207.csv
# Fetching data for Australia - House of Representatives - 2013
# Saved ../data/legislature_data/Australia_House of Representatives_2013_208.csv
# Fetching data for Australia - House of Representatives - 2004
# Saved ../data/legislature_data/Australia_House of Representatives_2004_209.csv
# Fetching data for Australia - House of Representatives - 2007
# Saved ../data/legislature_data/Australia_House of Representatives_2007_214.csv
# Fetching data for Australia - Senate - 2016
# Saved ../data/legislature_data/Australia_Senate_2016_215.csv
# Fetching data for Australia - Senate - 2013
# Saved ../data/legislature_data/Australia_Senate_2013_218.csv
# Fetching data for Sri-Lanka - Parliament - 2015
# Saved ../data/legislature_data/Sri-Lanka_Parliament_2015_229.csv
# Fetching data for Zambia - National Assembly - 2016
# Saved ../data/legislature_data/Zambia_National Assembly_2016_231.csv
# Fetching data for Zambia - National Assembly - 2011
# Saved ../data/legislature_data/Zambia_National Assembly_2011_232.csv
# Fetching data for Romania - Chamber of Deputies - 2016
# Saved ../data/legislature_data/Romania_Chamber of Deputies_2016_244.csv
# Fetching data for Netherlands - Tweede Kamer - 2017
# Saved ../data/legislature_data/Netherlands_Tweede Kamer_2017_248.csv
# Fetching data for Netherlands - Tweede Kamer - 2012
# Saved ../data/legislature_data/Netherlands_Tweede Kamer_2012_249.csv
# Fetching data for Guatemala - Congress - 2012
# Saved ../data/legislature_data/Guatemala_Congress_2012_250.csv
# Fetching data for Guatemala - Congress - 2016
# Saved ../data/legislature_data/Guatemala_Congress_2016_251.csv
# Fetching data for Zimbabwe - House of Assembly - 2013
# Saved ../data/legislature_data/Zimbabwe_House of Assembly_2013_253.csv
# Fetching data for Rwanda - Chamber of Deputies - 2013
# Saved ../data/legislature_data/Rwanda_Chamber of Deputies_2013_255.csv
# Fetching data for Belgium - Chamber of Representatives - 2014
# Saved ../data/legislature_data/Belgium_Chamber of Representatives_2014_262.csv
# Fetching data for Papua-New-Guinea - National Parliament - 2012
# Saved ../data/legislature_data/Papua-New-Guinea_National Parliament_2012_287.csv
# Fetching data for Greece - Hellenic Parliament - 2012
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2012_301.csv
# Fetching data for Greece - Hellenic Parliament - 2015
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2015_302.csv
# Fetching data for Greece - Hellenic Parliament - 2015
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2015_303.csv
# Fetching data for Greece - Hellenic Parliament - 2012
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2012_304.csv
# Fetching data for Greece - Hellenic Parliament - 2009
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2009_305.csv
# Fetching data for Greece - Hellenic Parliament - 2007
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2007_306.csv
# Fetching data for Greece - Hellenic Parliament - 2004
# Saved ../data/legislature_data/Greece_Hellenic Parliament_2004_307.csv
# Fetching data for Hungary - Országgyűlés - 2018
# Saved ../data/legislature_data/Hungary_Országgyűlés_2018_341.csv
# Fetching data for Hungary - Országgyűlés - 2014
# Saved ../data/legislature_data/Hungary_Országgyűlés_2014_342.csv
# Fetching data for Belarus - House of Representatives - 2016
# Saved ../data/legislature_data/Belarus_House of Representatives_2016_346.csv
# Fetching data for Hong-Kong - Legislative Council - 2012
# Saved ../data/legislature_data/Hong-Kong_Legislative Council_2012_365.csv
# Fetching data for Hong-Kong - Legislative Council - 2016
# Saved ../data/legislature_data/Hong-Kong_Legislative Council_2016_366.csv
# Fetching data for Nicaragua - National Assembly - 2012
# Saved ../data/legislature_data/Nicaragua_National Assembly_2012_369.csv
# Fetching data for Bulgaria - National Assembly - 2013
# Saved ../data/legislature_data/Bulgaria_National Assembly_2013_378.csv
# Fetching data for Bulgaria - National Assembly - 2017
# Saved ../data/legislature_data/Bulgaria_National Assembly_2017_381.csv
# Fetching data for Bulgaria - National Assembly - 2014
# Saved ../data/legislature_data/Bulgaria_National Assembly_2014_382.csv
# Fetching data for Denmark - Folketing - 2015
# Saved ../data/legislature_data/Denmark_Folketing_2015_385.csv
# Fetching data for Denmark - Folketing - 2001
# Saved ../data/legislature_data/Denmark_Folketing_2001_389.csv
# Fetching data for Denmark - Folketing - 2005
# Saved ../data/legislature_data/Denmark_Folketing_2005_390.csv
# Fetching data for Denmark - Folketing - 2007
# Saved ../data/legislature_data/Denmark_Folketing_2007_391.csv
# Fetching data for Denmark - Folketing - 2011
# Saved ../data/legislature_data/Denmark_Folketing_2011_392.csv
# Fetching data for Finland - Eduskunta - 2003
# Saved ../data/legislature_data/Finland_Eduskunta_2003_408.csv
# Fetching data for Finland - Eduskunta - 2015
# Saved ../data/legislature_data/Finland_Eduskunta_2015_409.csv
# Fetching data for Finland - Eduskunta - 2011
# Saved ../data/legislature_data/Finland_Eduskunta_2011_410.csv
# Fetching data for Finland - Eduskunta - 2007
# Saved ../data/legislature_data/Finland_Eduskunta_2007_417.csv
# Fetching data for Slovakia - National Council - 2012
# Saved ../data/legislature_data/Slovakia_National Council_2012_441.csv
# Fetching data for Slovakia - National Council - 2006
# Saved ../data/legislature_data/Slovakia_National Council_2006_442.csv
# Fetching data for Slovakia - National Council - 2016
# Saved ../data/legislature_data/Slovakia_National Council_2016_443.csv
# Fetching data for Slovakia - National Council - 2010
# Saved ../data/legislature_data/Slovakia_National Council_2010_444.csv
# Fetching data for New-Zealand - New Zealand Parliament - 2011
# Saved ../data/legislature_data/New-Zealand_New Zealand Parliament_2011_458.csv
# Fetching data for New-Zealand - New Zealand Parliament - 2017
# Saved ../data/legislature_data/New-Zealand_New Zealand Parliament_2017_460.csv
# Fetching data for New-Zealand - New Zealand Parliament - 2014
# Saved ../data/legislature_data/New-Zealand_New Zealand Parliament_2014_461.csv
# Fetching data for New-Zealand - New Zealand Parliament - 2008
# Saved ../data/legislature_data/New-Zealand_New Zealand Parliament_2008_462.csv
# Fetching data for Georgia - Parliament of Georgia - 2016
# Saved ../data/legislature_data/Georgia_Parliament of Georgia_2016_472.csv
# Fetching data for Georgia - Parliament of Georgia - 2012
# Saved ../data/legislature_data/Georgia_Parliament of Georgia_2012_473.csv
# Fetching data for Uruguay - Chamber of Deputies - 2015
# Saved ../data/legislature_data/Uruguay_Chamber of Deputies_2015_477.csv
# Fetching data for Bosnia-and-Herzegovina - House of Representatives - 2014
# Saved ../data/legislature_data/Bosnia-and-Herzegovina_House of Representatives_2014_480.csv
# Fetching data for Armenia - National Assembly - 2019
# Saved ../data/legislature_data/Armenia_National Assembly_2019_485.csv
# Fetching data for Albania - Kuvendi - 2017
# Saved ../data/legislature_data/Albania_Kuvendi_2017_488.csv
# Fetching data for Albania - Kuvendi - 2013
# Saved ../data/legislature_data/Albania_Kuvendi_2013_489.csv
# Fetching data for Albania - Kuvendi - 2009
# Saved ../data/legislature_data/Albania_Kuvendi_2009_490.csv
# Fetching data for Namibia - National Council - 2015
# Saved ../data/legislature_data/Namibia_National Council_2015_501.csv
# Fetching data for Namibia - National Assembly - 2015
# Saved ../data/legislature_data/Namibia_National Assembly_2015_503.csv
# Fetching data for Moldova - Parlament - 2014
# Saved ../data/legislature_data/Moldova_Parlament_2014_505.csv
# Fetching data for Macedonia - Sobranie - 2014
# Saved ../data/legislature_data/Macedonia_Sobranie_2014_514.csv
# Fetching data for Macedonia - Sobranie - 2016
# Saved ../data/legislature_data/Macedonia_Sobranie_2016_515.csv
# Fetching data for Estonia - Riigikogu - 2019
# Saved ../data/legislature_data/Estonia_Riigikogu_2019_520.csv
# Fetching data for Estonia - Riigikogu - 2011
# Saved ../data/legislature_data/Estonia_Riigikogu_2011_521.csv
# Fetching data for Estonia - Riigikogu - 2015
# Saved ../data/legislature_data/Estonia_Riigikogu_2015_522.csv
# Fetching data for Cyprus - House of Representatives - 2016
# Saved ../data/legislature_data/Cyprus_House of Representatives_2016_523.csv
# Fetching data for Bhutan - National Assembly - 2013
# Saved ../data/legislature_data/Bhutan_National Assembly_2013_532.csv
# Fetching data for Luxembourg - Chamber of Deputies - 2013
# Saved ../data/legislature_data/Luxembourg_Chamber of Deputies_2013_535.csv
# Fetching data for Luxembourg - Chamber of Deputies - 2018
# Saved ../data/legislature_data/Luxembourg_Chamber of Deputies_2018_536.csv
# Fetching data for Suriname - National Assembly - 2015
# Saved ../data/legislature_data/Suriname_National Assembly_2015_537.csv
# Fetching data for Malta - Parliament - 2017
# Saved ../data/legislature_data/Malta_Parliament_2017_542.csv
# Fetching data for Malta - Parliament - 2013
# Saved ../data/legislature_data/Malta_Parliament_2013_543.csv
# Fetching data for French-Polynesia - Assembly - 2013
# Saved ../data/legislature_data/French-Polynesia_Assembly_2013_559.csv
# Fetching data for Seychelles - National Assembly - 2011
# Saved ../data/legislature_data/Seychelles_National Assembly_2011_575.csv
# Fetching data for Andorra - Consell General - 2015
# Saved ../data/legislature_data/Andorra_Consell General_2015_596.csv
# Fetching data for Bermuda - Parliament - 2017
# Saved ../data/legislature_data/Bermuda_Parliament_2017_672.csv
# Fetching data for Greenland - Inatsisartut - 2014
# Saved ../data/legislature_data/Greenland_Inatsisartut_2014_687.csv
# Fetching data for Guernsey - States - 2016
# Saved ../data/legislature_data/Guernsey_States_2016_699.csv
# Fetching data for Jersey - States - 2014
# Saved ../data/legislature_data/Jersey_States_2014_701.csv
# Fetching data for Scotland - Scottish Parliament - 2016
# Saved ../data/legislature_data/Scotland_Scottish Parliament_2016_732.csv
# Fetching data for Scotland - Scottish Parliament - 2011
# Saved ../data/legislature_data/Scotland_Scottish Parliament_2011_733.csv
# Fetching data for Scotland - Scottish Parliament - 2007
# Saved ../data/legislature_data/Scotland_Scottish Parliament_2007_734.csv
# Fetching data for Wales - National Assembly for Wales - 2016
# Saved ../data/legislature_data/Wales_National Assembly for Wales_2016_748.csv
# Fetching data for Wales - National Assembly for Wales - 2011
# Saved ../data/legislature_data/Wales_National Assembly for Wales_2011_749.csv

# %%
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.shape
# Out:
# (25087, 20)

# %%
final_df = pd.merge(combined_df, sm_data, on="row_id", how="left")
list(final_df)
# Out:
# ['id',
#  'name',
#  'sort_name',
#  'email',
#  'twitter',
#  'facebook',
#  'group',
#  'group_id',
#  'area_id',
#  'area',
#  'chamber',
#  'term_x',
#  'start_date',
#  'end_date',
#  'image',
#  'gender',
#  'wikidata',
#  'wikidata_group',
#  'wikidata_area',
#  'row_id',
#  'country',
#  'legislature',
#  'term_y',
#  'leg_start_year',
#  'row_count',
#  'n_unique_emails',
#  'person_count_legistype',
#  'ltype',
#  'url',
#  'cc',
#  'leg_start_date',
#  'lastmod',
#  'cc3',
#  'pop2024',
#  'lastmod_year']

# %%
final_df.to_csv(os.path.join(output_folder, "everypol_combined_legislature_data.csv"), index=False)

# %%
# Get Unique emails for running through HIBP
pd.DataFrame(final_df['email'].unique(), columns=["email"]).to_csv("../data/everypol_unique_emails.csv", index = False)
